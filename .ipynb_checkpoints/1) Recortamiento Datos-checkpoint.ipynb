# %% [markdown]
# # Equipo 9:
# ## Integrantes:
# - CRUZ MIER SAMUEL
# - JIMENEZ QUIROZ ENYA EZTLI
# - REYES SANCHEZ LAURA PAMELA
# - MARTíNEZ FLORES PATRICIO SEBASTIÁN
# - MOSQUERA ALVAREZ JUAN DAVID
# - OSORIO MONTENEGRO JUAN DIEGO

# %% [markdown]
# # Preprocesamiento
#
# - limpieza de datos
#     - Datos faltantes
#     - Eliminación
#     - Sustitución (imputation)
# - Datos con ruido
#     - detección de anomalías
# - Transformación de datos
#     - Normalización / Estandarización
#     - Datos categóricos
#         - Con orden
#         - Sin orden
# - Reducción de dimensionalidad
#     - Análisis de componentes principales (PCA)
#     - Análisis de correspondencias múltiples (MCA)
#
# Datos anómalos se eliminan
# Datos faltantes se pueden sustituir con la moda, media o promedio
#
# Se normalizan los datos (datos de 0-1)
# Se estandarizan los datos (opcional)

# %%
import pandas as pd
import numpy as np
from io import StringIO
import pyreadstat

# %%
df=pd.read_spss('EDG_1990_2021.sav')

# %%
df
# Out:
#           prov_insc  cant_insc  parr_insc  anio_insc    mes_insc  dia_insc  \
# 0              Loja       Loja       Loja     1990.0       Julio       NaN
# 1              Loja       Loja       Loja     1990.0       Junio       NaN
# 2              Loja       Loja       Loja     1990.0  Septiembre       NaN
# 3             Azuay     Cuenca     Cuenca     1990.0      Agosto       NaN
# 4             Azuay     Cuenca     Cuenca     1990.0      Agosto       NaN
# ...             ...        ...        ...        ...         ...       ...
# 1982276      Manabí       Jama       Jama     2021.0   Diciembre      16.0
# 1982277  Chimborazo     Alausí     Alausí     2021.0       Marzo      23.0
# 1982278      El Oro   El Guabo   El Guabo     2021.0   Noviembre      11.0
# 1982279        Loja  Espíndola    Amaluza     2021.0      Agosto      30.0
# 1982280   Pichincha  Rumiñahui  Sangolquí     2021.0  Septiembre      21.0
#
# ...

# %%
sample_df = df.sample(frac=0.30, random_state=9)  # random_state es una semilla para la reproducibilidad
sample_df
# Out:
#                               prov_insc                        cant_insc  \
# 1188483                        Imbabura                     Antonio Ante
# 1168419                          El Oro                       Santa Rosa
# 1120649                          Guayas         Alfredo Baquerizo Moreno
# 333421                         Los Ríos                         Palenque
# 1088304                      Tungurahua                           Ambato
# ...                                 ...                              ...
# 1503784  Santo Domingo de los Tsachilas                    Santo Domingo
# 1741282                 Morona Santiago                       Gualaquiza
# 1750462                       Pichincha  Distrito Metropolitano de Quito
# 720701                      Santa Elena                      La Libertad
# 607111                           Manabí                       24 de Mayo
#
#                                 parr_insc  anio_insc   mes_insc  dia_insc  \
# ...

# %%
sample_df.to_csv('EDG_1990_2021_9.csv', index=False)

# %%
sample_df.isnull().sum()
# Out:
# prov_insc          0
# cant_insc          0
# parr_insc          0
# anio_insc        839
# mes_insc         839
# dia_insc      385559
# fecha_insc    385684
# nac_fall      384720
# cod_pais           0
# sexo               0
# anio_nac           0
# mes_nac            0
# dia_nac       384720
# anio_fall          0
# mes_fall           0
# dia_fall      384720
# fecha_fall    384720
# cod_edad           0
# edad               0
# prov_res           0
# cant_res           0
# parr_res           0
# est_civil      59993
# sabe_leer      55875
# etnia         310898
# lugar_ocur         0
# prov_fall          0
# cant_fall          0
# parr_fall          0
# muj_fertil    586835
# mor_viol      530806
# lug_viol      568686
# autopsia      360155
# niv_inst       54563
# fecha_nac     384887
# causa9             0
# cer_por            0
# anio_base          0
# total              0
# area_fall          0
# area_res           0
# causa3             0
# causa              0
# ...
